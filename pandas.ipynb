# %% [markdown]
# <a href="https://colab.research.google.com/github/kavyasasikumar07/pandas-python/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
a=np.array([10,12,12,44,55])
a
# Out:
# array([10, 12, 12, 44, 55])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a[1]
# Out:
# 12

# %%
s=pd.Series([10,12,13,44,56])
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# 0    10
# 1    12
# 2    13
# 3    44
# 4    56
# dtype: int64

# %%
s[3]
# Out:
# 44

# %%
s.drop(3,inplace=True)

# %%
s
# Out:
# array([1, 2, 3])

# %%
s.iloc[3]   #index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-209-feb6eed59fdb> in <cell line: 1>()
# ----> 1 s.iloc[3]   #index
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iloc'

# %%
s.index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-211-618a1b6df4c9> in <cell line: 1>()
# ----> 1 s.index
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
ss=pd.Series([10,12,13,44,56],index=['a','a','c','d','e'])
ss
# Out:
# a    10
# a    12
# c    13
# d    44
# e    56
# dtype: int64

# %%
ss.iloc[2]
# Out:
# 13

# %%
ss.loc['c']
# Out:
# 13

# %%
ss.loc['a']
# Out:
# a    10
# a    12
# dtype: int64

# %%
data=[['alex',10,'23-05-2000'],['bob',None,None],['charlie',None,'23-05-2003']]

# %%
a=pd.Series([10,12,13,44,56])
a.drop(3,inplace=True)
a
# Out:
# 0    10
# 1    12
# 2    13
# 4    56
# dtype: int64

# %%
a.iloc[3]
# Out:
# 56

# %%
data=[['alex',10,'23-05-2000'],['bob',None,None],['charlie',None,'23-05-2003']]
data
# Out:
# [['alex', 10, '23-05-2000'],
#  ['bob', None, None],
#  ['charlie', None, '23-05-2003']]

# %%
df=pd.DataFrame(data)
df
# Out:
#          0     1           2
# 0     alex  10.0  23-05-2000
# 1      bob   NaN        None
# 2  charlie   NaN  23-05-2003

# %%
df[0][0]
# Out:
# 'alex'

# %%
df[[0,2]]
# Out:
#          0           2
# 0     alex  23-05-2000
# 1      bob        None
# 2  charlie  23-05-2003

# %%
df[1:2]
# Out:
#   firstname  age   DOB
# 1       bob  NaN  None

# %%
df=pd.DataFrame(data,columns=['firstname','age','DOB'])
df
# Out:
#   firstname   age         DOB
# 0      alex  10.0  23-05-2000
# 1       bob   NaN        None
# 2   charlie   NaN  23-05-2003

# %%
df['firstname']
# Out:
# 0       alex
# 1        bob
# 2    charlie
# Name: firstname, dtype: object

# %%
df['age']
# Out:
# 0    10.0
# 1     NaN
# 2     NaN
# Name: age, dtype: float64

# %%
df['firstname'][0]
# Out:
# 'alex'

# %%
df.loc[0,'firstname']
# Out:
# 'alex'

# %%
df.iloc[0]
# Out:
# firstname          alex
# age                10.0
# DOB          23-05-2000
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# firstname          alex
# age                10.0
# DOB          23-05-2000
# Name: 0, dtype: object

# %%
df[0:1]
# Out:
#   firstname   age         DOB
# 0      alex  10.0  23-05-2000

# %%
s=pd.Series([1,2,3])
s
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s.plot()
# Out:
# <Axes: >

# %%
s.hist(bins=2)
# Out:
# <Axes: >

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s=s.to_numpy() #covert series to numpy

# %%
type(s)
# Out:
# numpy.ndarray

# %%
df
# Out:
#   firstname   age         DOB
# 0      alex  10.0  23-05-2000
# 1       bob   NaN        None
# 2   charlie   NaN  23-05-2003

# %%
df.head()
# Out:
#   firstname   age         DOB
# 0      alex  10.0  23-05-2000
# 1       bob   NaN        None
# 2   charlie   NaN  23-05-2003

# %%
df.head(1)
# Out:
#   firstname   age         DOB
# 0      alex  10.0  23-05-2000

# %%
df.tail()
# Out:
#   firstname   age         DOB
# 0      alex  10.0  23-05-2000
# 1       bob   NaN        None
# 2   charlie   NaN  23-05-2003

# %%
df.tail(0)
# Out:
# Empty DataFrame
# Columns: [firstname, age, DOB]
# Index: []

# %%
df.tail(1)
# Out:
#   firstname  age         DOB
# 2   charlie  NaN  23-05-2003

# %%
df.tail(2)
# Out:
#   firstname  age         DOB
# 1       bob  NaN        None
# 2   charlie  NaN  23-05-2003

# %%
df.tail(-1)
# Out:
#   firstname  age         DOB
# 1       bob  NaN        None
# 2   charlie  NaN  23-05-2003

# %%
df.tail(-2)
# Out:
#   firstname  age         DOB
# 2   charlie  NaN  23-05-2003

# %%
# None,' ','','-','?','Nil',np.nan(not a number)  refers all are same

# %%
df
# Out:
#   firstname   age         DOB
# 0      alex  10.0  23-05-2000
# 1       bob   NaN        None
# 2   charlie   NaN  23-05-2003

# %%
df.isnull()
# Out:
#    firstname    age    DOB
# 0      False  False  False
# 1      False   True   True
# 2      False   True  False

# %%
df.to_numpy()
# Out:
# array([['alex', 10.0, '23-05-2000'],
#        ['bob', nan, None],
#        ['charlie', nan, '23-05-2003']], dtype=object)

# %%
df.isnull().sum()
# Out:
# firstname    0
# age          2
# DOB          1
# dtype: int64

# %%
a=pd.DataFrame([['Abi',None,None],['Boomi',12,'15/8/23'],['Deeksha',None,None],[None,12,'30/2/23']])
a
# Out:
#          0     1        2
# 0      Abi   NaN     None
# 1    Boomi  12.0  15/8/23
# 2  Deeksha   NaN     None
# 3     None  12.0  30/2/23

# %%
a.isnull()
# Out:
#        0      1      2
# 0  False   True   True
# 1  False  False  False
# 2  False   True   True
# 3   True  False  False

# %%
a.isnull().sum() #column sums
# Out:
# 0    1
# 1    2
# 2    2
# dtype: int64

# %%
a.dropna()
# Out:
#        0     1        2
# 1  Boomi  12.0  15/8/23

# %%
a.dropna()
# Out:
#        0     1        2
# 1  Boomi  12.0  15/8/23

# %%
a
# Out:
#          0     1        2
# 0      Abi   NaN     None
# 1    Boomi  12.0  15/8/23
# 2  Deeksha   NaN     None
# 3     None  12.0  30/2/23

# %%
df
# Out:
#   firstname   age         DOB
# 0      alex  10.0  23-05-2000
# 1       bob   NaN        None
# 2   charlie   NaN  23-05-2003

# %%
df.drop?  #help manual
# Out:
#   File "<ipython-input-230-288c33798f75>", line 1
#     df.drop?  #help manual
#            ^
# SyntaxError: invalid syntax

# %%
a
# Out:
#          0     1        2
# 0      Abi   NaN     None
# 1    Boomi  12.0  15/8/23
# 2  Deeksha   NaN     None
# 3     None  12.0  30/2/23

# %%
df
# Out:
#   firstname   age         DOB
# 0      alex  10.0  23-05-2000
# 1       bob   NaN        None
# 2   charlie   NaN  23-05-2003

# %%
df.drop(['age'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-165-4a38489ce18d> in <cell line: 1>()
# ----> 1 df.drop(['age'],axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
df
# Out:
#   firstname         DOB
# 0      alex  23-05-2000
# 1       bob        None
# 2   charlie  23-05-2003

# %%
df.drop([0, 1]) #both are rows
# Out:
#   firstname         DOB
# 2   charlie  23-05-2003

# %%
df
# Out:
#   firstname         DOB
# 0      alex  23-05-2000
# 1       bob        None
# 2   charlie  23-05-2003

# %%
df.drop([0,1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-190-54b5ff136755> in <cell line: 1>()
# ----> 1 df.drop([0,1])
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
df
# Out:
#   firstname         DOB
# 2   charlie  23-05-2003

# %%
df
# Out:
#   firstname         DOB
# 2   charlie  23-05-2003

# %%
a>40
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-179-32a94905c724> in <cell line: 1>()
# ----> 1 a>40
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __gt__(self, other)
#      56     @unpack_zerodim_and_defer("__gt__")
#      57     def __gt__(self, other):
# ---> 58         return self._cmp_method(other, operator.gt)
#      59
#      60     @unpack_zerodim_and_defer("__ge__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _cmp_method(self, other, op)
#    7580
#    7581         # See GH#4537 for discussion of scalar op behavior
# ...

# %%
a=pd.Series([10,12,12,44,55])
a
# Out:
# 0    10
# 1    12
# 2    12
# 3    44
# 4    55
# dtype: int64

# %%
a=a.to_numpy()

# %%
a
# Out:
# array([10, 12, 12, 44, 55])

# %%
a>40 #value in bool(check)
# Out:
# array([False, False, False,  True,  True])

# %%
a[a>40]
# Out:
# array([44, 55])

# %%
a=a[a%2!=0]
a
# Out:
# array([55])

# %%
df
# Out:
#          0     1           2
# 0     alex  10.0  23-05-2000
# 1      bob   NaN        None
# 2  charlie   NaN  23-05-2003

# %%
df.info
# Out:
# <bound method DataFrame.info of          0     1           2
# 0     alex  10.0  23-05-2000
# 1      bob   NaN        None
# 2  charlie   NaN  23-05-2003>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   firstname  3 non-null      object
#  1   age        1 non-null      float64
#  2   DOB        2 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 200.0+ bytes

# %%
df['firstname'].str.contains('e')
# Out:
# 0     True
# 1    False
# 2     True
# Name: firstname, dtype: bool

# %%
df['firstname'].str.contains('b')
# Out:
# 0    False
# 1     True
# 2    False
# Name: firstname, dtype: bool

# %%
print(df.shape)
print(df.size)
print(df.axes)
print(df.ndim)
print(df.dtypes)
print(df.index)
print(df.columns)
print(df.values)
# Out:
# (3, 3)
# 9
# [RangeIndex(start=0, stop=3, step=1), Index(['firstname', 'age', 'DOB'], dtype='object')]
# 2
# firstname     object
# age          float64
# DOB           object
# dtype: object
# RangeIndex(start=0, stop=3, step=1)
# Index(['firstname', 'age', 'DOB'], dtype='object')
# [['alex' 10.0 '23-05-2000']
#  ['bob' nan None]
#  ['charlie' nan '23-05-2003']]

# %%
df2=pd.concat([df,df])
df
# Out:
#          0     1           2
# 0     alex  10.0  23-05-2000
# 1      bob   NaN        None
# 2  charlie   NaN  23-05-2003

# %%
df.describe(include='all')
# Out:
#            0     1           2
# count      3   1.0           2
# unique     3   NaN           2
# top     alex   NaN  23-05-2000
# freq       1   NaN           1
# mean     NaN  10.0         NaN
# std      NaN   NaN         NaN
# min      NaN  10.0         NaN
# 25%      NaN  10.0         NaN
# 50%      NaN  10.0         NaN
# 75%      NaN  10.0         NaN
# max      NaN  10.0         NaN

# %%
df[0]
# Out:
# 0       alex
# 1        bob
# 2    charlie
# Name: 0, dtype: object

# %%
df=pd.DataFrame(data,columns=['firstname','age','dob'])
df
# Out:
#   firstname   age         dob
# 0      alex  10.0  23-05-2000
# 1       bob   NaN        None
# 2   charlie   NaN  23-05-2003

# %%
df.dob
# Out:
# 0    23-05-2000
# 1          None
# 2    23-05-2003
# Name: dob, dtype: object

# %%
df[['firstname','dob']]
# Out:
#   firstname         dob
# 0      alex  23-05-2000
# 1       bob        None
# 2   charlie  23-05-2003

# %%
df.loc[0][0]
# Out:
# 'alex'

# %%
df.loc[0,'firstname']
# Out:
# 'alex'

# %%
df.iloc[0]
# Out:
# firstname          alex
# age                10.0
# dob          23-05-2000
# Name: 0, dtype: object

# %%
df.iloc[0,0]
# Out:
# 'alex'

# %%
df.iloc[0,2]
# Out:
# '23-05-2000'

# %%
df["dob"][1]='30-3-2004'
# Out:
# <ipython-input-260-e1c8d179d2d3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["dob"][1]='30-3-2004'

# %%
df
# Out:
#   firstname   age         dob
# 0      alex  10.0  23-05-2000
# 1       bob   NaN   30-3-2004
# 2   charlie   NaN  23-05-2003

# %%
df=pd.read_html("https://en.wikipedia.org/wiki/English_Wikipedia")
df
# Out:
# [                                                   0  \
#  0                                                NaN
#  1  .mw-parser-output .hidden-begin{box-sizing:bor...
#  2                                       Type of site
#  3                                              Owner
#  4                                                URL
#  5                                         Commercial
#  6                                       Registration
#  7                                              Users
#  8                                           Launched
#  9                                    Content license
#
#                                                     1
#  0                                                NaN
#  1  .mw-parser-output .hidden-begin{box-sizing:bor...
#  2                              Internet encyclopedia
#  3                               Wikimedia Foundation
#  4                                   en.wikipedia.org
# ...

# %%
df=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.isnull()
# Out:
#       order_id  quantity  item_name  choice_description  item_price
# 0        False     False      False                True       False
# 1        False     False      False               False       False
# 2        False     False      False               False       False
# 3        False     False      False                True       False
# 4        False     False      False               False       False
# ...        ...       ...        ...                 ...         ...
# 4617     False     False      False               False       False
# 4618     False     False      False               False       False
# 4619     False     False      False               False       False
# 4620     False     False      False               False       False
# 4621     False     False      False               False       False
#
# [4622 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df.item_price=df.item_price.str.replace('$','')
df.head(10)
# Out:
# <ipython-input-29-5f86cc00013c>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.item_price=df.item_price.str.replace('$','')
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
# ...

# %%
df.item_price=df.item_price.astype(float)

# %%
type(df.item_price[0])
# Out:
# numpy.float64

# %%
#df=(df.item_price)*100
#df
# Out:
# 0        239.0
# 1        339.0
# 2        339.0
# 3        239.0
# 4       1698.0
#          ...
# 4617    1175.0
# 4618    1175.0
# 4619    1125.0
# 4620     875.0
# 4621     875.0
# Name: item_price, Length: 4622, dtype: float64

# %%
df_drink=df[df.item_price < 1.1]

# %%
df_drink
# Out:
#       order_id  quantity      item_name choice_description  item_price
# 28          14         1    Canned Soda       [Dr. Pepper]        1.09
# 34          17         1  Bottled Water                NaN        1.09
# 53          24         1    Canned Soda           [Sprite]        1.09
# 87          38         1  Bottled Water                NaN        1.09
# 107         47         1    Canned Soda       [Dr. Pepper]        1.09
# ...        ...       ...            ...                ...         ...
# 3936      1578         1    Canned Soda  [Diet Dr. Pepper]        1.09
# 4001      1602         1  Bottled Water                NaN        1.09
# 4008      1604         1    Canned Soda        [Diet Coke]        1.09
# 4051      1621         1    Canned Soda           [Sprite]        1.09
# 4069      1629         1  Bottled Water                NaN        1.09
#
# [106 rows x 5 columns]

# %%
df_drink.item_name.unique()
# Out:
# array(['Canned Soda', 'Bottled Water'], dtype=object)

# %%
df_drink.item_name.nunique()
# Out:
# 2

# %%
df_drink.item_name.value_counts()
# Out:
# Canned Soda      84
# Bottled Water    22
# Name: item_name, dtype: int64

# %%
df[df.item_name=='Chicken Bowl']
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# ...                                                 ...         ...
# ...

# %%
df[df.item_name=='Steak Burrito']
# Out:
#       order_id  quantity      item_name  \
# 7            4         1  Steak Burrito
# 9            5         1  Steak Burrito
# 31          16         1  Steak Burrito
# 43          20         1  Steak Burrito
# 46          21         1  Steak Burrito
# ...        ...       ...            ...
# 4546      1807         1  Steak Burrito
# 4607      1829         1  Steak Burrito
# 4610      1830         1  Steak Burrito
# 4617      1833         1  Steak Burrito
# 4618      1833         1  Steak Burrito
#
#                                      choice_description  item_price
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        9.25
# 31    [[Roasted Chili Corn Salsa (Medium), Fresh Tom...        8.99
# 43    [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...       11.75
# 46    [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...        8.99
# ...                                                 ...         ...
# ...

# %%
df[df.item_name=='Steak Burrito'].choice_description
# Out:
# 7       [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 9       [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...
# 31      [[Roasted Chili Corn Salsa (Medium), Fresh Tom...
# 43      [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...
# 46      [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...
#                               ...
# 4546    [Fresh Tomato Salsa, [Rice, Black Beans, Cheese]]
# 4607    [Tomatillo Green Chili Salsa, [Rice, Cheese, S...
# 4610    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4617    [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# Name: choice_description, Length: 368, dtype: object

# %%
df[df.item_name=='Steak Burrito'].order_id
# Out:
# 7          4
# 9          5
# 31        16
# 43        20
# 46        21
#         ...
# 4546    1807
# 4607    1829
# 4610    1830
# 4617    1833
# 4618    1833
# Name: order_id, Length: 368, dtype: int64

# %%
df[df.item_name=='Steak Burrito'].choice_description.value_counts()
# Out:
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice, Cheese, Sour Cream]]                                                        12
# [Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]                                     6
# [Tomatillo Green Chili Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]                                        6
# [[Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]     5
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                            5
#                                                                                                                             ..
# [Fresh Tomato Salsa, [Rice, Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettuce]]                                    1
# ...

# %%
df[df.item_name=='Steak Burrito'].choice_description.nunique()
# Out:
# 251

# %%
df.choice_description
# Out:
# 0                                                     NaN
# 1                                            [Clementine]
# 2                                                 [Apple]
# 3                                                     NaN
# 4       [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
#                               ...
# 4617    [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4619    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# 4620    [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...
# 4621    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# Name: choice_description, Length: 4622, dtype: object

# %%
df.dropna(inplace=True)

# %%
df[df.choice_description.str.contains('Black Beans')].item_name
# Out:
# 4               Chicken Bowl
# 7              Steak Burrito
# 9              Steak Burrito
# 11      Chicken Crispy Tacos
# 12        Chicken Soft Tacos
#                 ...
# 4604            Chicken Bowl
# 4608          Veggie Burrito
# 4611          Veggie Burrito
# 4612           Carnitas Bowl
# 4617           Steak Burrito
# Name: item_name, Length: 1345, dtype: object

# %%
df[df.choice_description.str.contains('Black Beans')].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
df[(df.item_price<10) & (df.item_name=='Chicken Bowl')].sort_values(['item_price'])
# Out:
#       order_id  quantity     item_name  \
# 3664      1466         1  Chicken Bowl
# 2918      1160         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 3396      1362         1  Chicken Bowl
# 1645       665         1  Chicken Bowl
# ...        ...       ...           ...
# 1876       759         1  Chicken Bowl
# 1852       751         1  Chicken Bowl
# 1851       750         1  Chicken Bowl
# 1829       740         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 3664  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 2918  [Fresh Tomato (Mild), [Rice, Sour Cream, Cheese]]        8.19
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 3396  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 1645  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...        8.49
# ...                                                 ...         ...
# ...

# %%
c=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")

# %%
c.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
c[(c.star_rating>9)&(c.content_rating=='R')]
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %%
c[(c.star_rating>9)&(c.content_rating=='R')].sort_values(['title'])
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
# 0          9.3  The Shawshank Redemption              R  Crime       142
#
#                                          actors_list
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...

# %%
c[(c.star_rating>9)&(c.content_rating=='R')].duration.value_counts()
# Out:
# 142    1
# 175    1
# 200    1
# Name: duration, dtype: int64

# %%
c[(c.star_rating>8)&(c.content_rating=='R')]
# Out:
#      star_rating                     title content_rating      genre  \
# 0            9.3  The Shawshank Redemption              R      Crime
# 1            9.2             The Godfather              R      Crime
# 2            9.1    The Godfather: Part II              R      Crime
# 4            8.9              Pulp Fiction              R      Crime
# 8            8.9          Schindler's List              R  Biography
# ..           ...                       ...            ...        ...
# 281          8.1            The Terminator              R     Action
# 283          8.1             Before Sunset              R      Drama
# 288          8.1               Sling Blade              R      Drama
# 290          8.1                 Prisoners              R      Crime
# 296          8.1            The Wild Bunch              R     Action
#
#      duration                                        actors_list
# 0         142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# ...

# %%
c[(c.star_rating>8)&(c.content_rating=='R')].sort_values(['duration'])
# Out:
#      star_rating                        title content_rating      genre  \
# 283          8.1                Before Sunset              R      Drama
# 225          8.1                       3-Iron              R      Crime
# 206          8.1                  Stand by Me              R  Adventure
# 172          8.2                Trainspotting              R      Drama
# 190          8.2                Life of Brian              R     Comedy
# ..           ...                          ...            ...        ...
# 184          8.2          Fanny and Alexander              R      Drama
# 40           8.5               The Green Mile              R      Crime
# 8            8.9             Schindler's List              R  Biography
# 2            9.1       The Godfather: Part II              R      Crime
# 78           8.4  Once Upon a Time in America              R      Crime
#
#      duration                                        actors_list
# ...

# %%
c[c.actors_list.str.contains('Robert De Niro')]
# Out:
#      star_rating                        title content_rating      genre  \
# 2            9.1       The Godfather: Part II              R      Crime
# 18           8.7                   Goodfellas              R  Biography
# 78           8.4  Once Upon a Time in America              R      Crime
# 92           8.4                  Taxi Driver              R      Crime
# 124          8.3                  Raging Bull              R  Biography
# 135          8.3                         Heat              R     Action
# 156          8.2                       Casino              R  Biography
# 166          8.2              The Deer Hunter              R      Drama
# 321          8.0                       Brazil              R     Sci-Fi
# 383          8.0             The Untouchables              R      Crime
# 475          7.8      Silver Linings Playbook              R     Comedy
# 571          7.8                 A Bronx Tale              R      Crime
# ...

# %%
c[c.actors_list.str.contains('Robert De Niro')].sort_values(['star_rating','duration'],ascending=[False,True])
# Out:
#      star_rating                        title content_rating      genre  \
# 2            9.1       The Godfather: Part II              R      Crime
# 18           8.7                   Goodfellas              R  Biography
# 92           8.4                  Taxi Driver              R      Crime
# 78           8.4  Once Upon a Time in America              R      Crime
# 124          8.3                  Raging Bull              R  Biography
# 135          8.3                         Heat              R     Action
# 156          8.2                       Casino              R  Biography
# 166          8.2              The Deer Hunter              R      Drama
# 383          8.0             The Untouchables              R      Crime
# 321          8.0                       Brazil              R     Sci-Fi
# 580          7.8           The King of Comedy             PG     Comedy
# 571          7.8                 A Bronx Tale              R      Crime
# ...

# %%
d=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")

# %%
d
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
d.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
d.dropna()
# Out:
#                City Colors Reported Shape Reported State              Time
# 12           Belton             RED         SPHERE    SC   6/30/1939 20:00
# 19       Bering Sea             RED          OTHER    AK   4/30/1943 23:00
# 36       Portsmouth             RED      FORMATION    VA    7/10/1945 1:30
# 44        Blairsden           GREEN         SPHERE    CA   6/30/1946 19:00
# 82         San Jose            BLUE        CHEVRON    CA   7/15/1947 21:00
# ...             ...             ...            ...   ...               ...
# 18213      Pasadena           GREEN       FIREBALL    CA  12/28/2000 19:10
# 18216  Garden Grove          ORANGE          LIGHT    CA  12/29/2000 16:10
# 18220   Shasta Lake            BLUE           DISK    CA  12/29/2000 20:30
# 18233     Anchorage             RED        VARIOUS    AK  12/31/2000 21:00
# 18239   Eagle River             RED          LIGHT    WI  12/31/2000 23:45
#
# [2486 rows x 5 columns]

# %%
d.dropna(how="all")
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
d.dropna(subset=['City','Shape Reported'],how='any').shape
# Out:
# (15576, 5)

# %%
d.dropna(subset=['City','Shape Reported'],how='all').shape
# Out:
# (18237, 5)

# %%
d['Shape Reported'].isnull().sum()
# Out:
# 2644

# %%
d['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
m=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")
m.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
m.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
m.beer_servings.min()
# Out:
# 0

# %%
m.beer_servings.max()
# Out:
# 376

# %%
m[m.continent=='Asia'].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
m[m.continent=='Asia'].beer_servings.agg(['mean','min','max'])
# Out:
# mean     37.045455
# min       0.000000
# max     247.000000
# Name: beer_servings, dtype: float64

# %%
m.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
m.groupby('continent').beer_servings.agg(['max','min','mean'])
# Out:
#                max  min        mean
# continent
# Africa         376    0   61.471698
# Asia           247    0   37.045455
# Europe         361    0  193.777778
# North America  285    1  145.434783
# Oceania        306    0   89.687500
# South America  333   93  175.083333
